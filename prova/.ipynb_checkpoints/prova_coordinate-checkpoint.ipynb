# %% [markdown]
# # Prova lettura file excel

# %%
import os

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints', 'Coordinate.csv', 'prova.ipynb']

# %%
from pandas import *
import pandas as pd

# %%
data = pd.ExcelFile('Coordinate.xlsx')
data

# %%
data.sheet_names
# Out:
# ['Coordinate']

# %%
pd.set_option('display.max_rows', 100)
df = data.parse('Coordinate')
df = df.set_index("PUNTO")
df = df.sort_index()
df
# Out:
#        COORDINATA_EST  COORDINATA_NORD
# PUNTO
# 1001              5.0              4.5
# 1002             13.5              6.0
# 1003             24.0              6.0
# 1004              6.0             12.0
# 1005             20.5             10.5
# 1006              2.0             16.5
# 1007             17.5             15.0
# 1008             23.0             14.5
# 1009             13.0             18.5
# 1010              3.5             22.0
# 1011             23.5             22.5
# 1012             11.5             24.0
# 1013              7.0             29.0
# 1014             16.0             30.0
# 1015              3.0             34.0
# 1016             10.0             32.0
# 1017             21.5             35.5
# 1018             12.5             38.5

# %%
df.sort_values('COORDINATA_EST')
# Out:
#        COORDINATA_EST  COORDINATA_NORD
# PUNTO
# 1006              2.0             16.5
# 1015              3.0             34.0
# 1010              3.5             22.0
# 1001              5.0              4.5
# 1004              6.0             12.0
# 1013              7.0             29.0
# 1016             10.0             32.0
# 1012             11.5             24.0
# 1018             12.5             38.5
# 1009             13.0             18.5
# 1002             13.5              6.0
# 1014             16.0             30.0
# 1007             17.5             15.0
# 1005             20.5             10.5
# 1017             21.5             35.5
# 1008             23.0             14.5
# 1011             23.5             22.5
# 1003             24.0              6.0

# %%
df.sort_values('COORDINATA_NORD')
# Out:
#        COORDINATA_EST  COORDINATA_NORD
# PUNTO
# 1001              5.0              4.5
# 1002             13.5              6.0
# 1003             24.0              6.0
# 1005             20.5             10.5
# 1004              6.0             12.0
# 1008             23.0             14.5
# 1007             17.5             15.0
# 1006              2.0             16.5
# 1009             13.0             18.5
# 1010              3.5             22.0
# 1011             23.5             22.5
# 1012             11.5             24.0
# 1013              7.0             29.0
# 1014             16.0             30.0
# 1016             10.0             32.0
# 1015              3.0             34.0
# 1017             21.5             35.5
# 1018             12.5             38.5

# %%
import matplotlib as plt
# %matplotlib inline

# %%
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000020995B59198>,
# ...
#       dtype=object)
