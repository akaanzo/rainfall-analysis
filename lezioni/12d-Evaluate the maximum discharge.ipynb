# %% [markdown]
# <h2>Calcolo della massima portata in un nodo</h2>
# (E' necessario aver svolto le simulazioni per tutti i tempi di pioggia)

# %% [markdown]
# Si carica la libreria che consente di conoscere e scegliere la directory di lavoro

# %%
import os
os.getcwd()
# Out:
# 'D:\\git\\jupyter\\lezioni\\lezione20190411'

# %% [markdown]
# Il comando seguente cambia la directory di lavoro. Scegliere la cartella dove sono presenti i file di <em>.inp</em>

# %%
os.chdir("D:\\git\\jupyter\\lezioni\\lezione20190411\\")

# %% [markdown]
# Si interroga ora la lista dei file presenti nella nuova directory di lavoro. Se corretta sono presenti le cartelle relative alle simulazioni per ogni tempo di pioggia. (5mins, 10mins,...)

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints', 'test20190411.csv']

# %% [markdown]
# Finalmente si importa la libreria "pandas"

# %%
from pandas import *
import pandas as pd

# %% [markdown]
# Si legge il file csv del nodo contenente le portate nel tempo per i diversi tempi di pioggia, usando il comando di panda <code>read_csv</code>

# %%
node_N1 = pd.read_csv('test20190411.csv')

# %% [markdown]
# Si visualizzano i dataframe per assicurarsi sia tutto corretto

# %%
node_N1
# Out:
#            time  5mins  10mins
# 0      00:00:30   0.00    0.00
# 1      00:01:00   0.01    0.01
# 2    00:01:30     0.03    0.02
# 3    00:02:00     0.04    0.03
# 4    00:02:30     0.07    0.05
# 5    00:03:00     0.09    0.06
# 6    00:03:30     0.12    0.08
# 7    00:04:00     0.15    0.10
# 8    00:04:30     0.18    0.13
# 9    00:05:00     0.22    0.15
# 10   00:05:30     0.23    0.18
# 11   00:06:00     0.23    0.21
# 12   00:06:30     0.22    0.23
# 13   00:07:00     0.22    0.26
# 14   00:07:30     0.22    0.29
# 15   00:08:00     0.22    0.33
# 16   00:08:30     0.21    0.36
# 17   00:09:00     0.21    0.39
# 18   00:09:30     0.21    0.42
# 19   00:10:00     0.20    0.46
# 20   00:10:30     0.20    0.46
# 21   00:11:00     0.20    0.46
# 22   00:11:30     0.20    0.45
# 23   00:12:00     0.19    0.44
# 24   00:12:30     0.19    0.43
# 25   00:13:00     0.19    0.43
# 26   00:13:30     0.19    0.42
# 27   00:14:00     0.19    0.41
# 28   00:14:30     0.18    0.40
# ...

# %% [markdown]
# I dati nel dataframe hanno come prima colonna gli anni. Si vuole invece che gli anni diventino l'indice dei dati (e
# naturalmente che il valore degli anni sia riconosciuto come una data, nel senso una data come "anno-mese-giorno" lo è). Il pacchetto datetime fa quest'ultimo servizio.

# %%
import datetime as datetime

# %%
node_N1=node_N1.set_index('time')

# %% [markdown]
# Visualizzando il dataframe si nota che <em>time</em> e' ora un indice

# %%
node_N1
# Out:
#             5mins  10mins
# time
# 00:00:30     0.00    0.00
# 00:01:00     0.01    0.01
# 00:01:30     0.03    0.02
# 00:02:00     0.04    0.03
# 00:02:30     0.07    0.05
# 00:03:00     0.09    0.06
# 00:03:30     0.12    0.08
# 00:04:00     0.15    0.10
# 00:04:30     0.18    0.13
# 00:05:00     0.22    0.15
# 00:05:30     0.23    0.18
# 00:06:00     0.23    0.21
# 00:06:30     0.22    0.23
# 00:07:00     0.22    0.26
# 00:07:30     0.22    0.29
# 00:08:00     0.22    0.33
# 00:08:30     0.21    0.36
# 00:09:00     0.21    0.39
# 00:09:30     0.21    0.42
# 00:10:00     0.20    0.46
# 00:10:30     0.20    0.46
# 00:11:00     0.20    0.46
# 00:11:30     0.20    0.45
# 00:12:00     0.19    0.44
# 00:12:30     0.19    0.43
# 00:13:00     0.19    0.43
# 00:13:30     0.19    0.42
# 00:14:00     0.19    0.41
# 00:14:30     0.18    0.40
# 00:15:00     0.18    0.40
# ...           ...     ...
# 04:45:30     0.01    0.01
# 04:46:00     0.01    0.01
# 04:46:30     0.01    0.01
# ...

# %% [markdown]
# Finalmente visualizziamo i dati con matplotlib. Il secondo comando, preceduto da "%" consente di visualizzare automaticamente sullo schermo il risultato grafico.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Si visualizzano le curve di portata rispetto all'andamento nel tempo per un controllo ulteriore

# %%
all=node_N1[['5mins','10mins']]

# %%
all
# Out:
#             5mins  10mins
# time
# 00:00:30     0.00    0.00
# 00:01:00     0.01    0.01
# 00:01:30     0.03    0.02
# 00:02:00     0.04    0.03
# 00:02:30     0.07    0.05
# 00:03:00     0.09    0.06
# 00:03:30     0.12    0.08
# 00:04:00     0.15    0.10
# 00:04:30     0.18    0.13
# 00:05:00     0.22    0.15
# 00:05:30     0.23    0.18
# 00:06:00     0.23    0.21
# 00:06:30     0.22    0.23
# 00:07:00     0.22    0.26
# 00:07:30     0.22    0.29
# 00:08:00     0.22    0.33
# 00:08:30     0.21    0.36
# 00:09:00     0.21    0.39
# 00:09:30     0.21    0.42
# 00:10:00     0.20    0.46
# 00:10:30     0.20    0.46
# 00:11:00     0.20    0.46
# 00:11:30     0.20    0.45
# 00:12:00     0.19    0.44
# 00:12:30     0.19    0.43
# 00:13:00     0.19    0.43
# 00:13:30     0.19    0.42
# 00:14:00     0.19    0.41
# 00:14:30     0.18    0.40
# 00:15:00     0.18    0.40
# ...           ...     ...
# 04:45:30     0.01    0.01
# 04:46:00     0.01    0.01
# 04:46:30     0.01    0.01
# ...

# %%
all.plot(style="-o")

# %% [markdown]
# Si valuta il valore massimo di portata tra i massimi ottenuti per tempi diversi di pioggia e il relativo tempo critico

# %%
n_t1=node_N1["5mins"]
n_t2=node_N1["10mins"]

# %%
maxValues = [n_t1.max(0), n_t2.max(0)]

# %%
maxValues
# Out:
# [0.23, 0.46]

# %%
maxValue = max(maxValues)

# %% [markdown]
# Il valore di <em>Q_max</em> e' quindi:

# %%
maxValue
# Out:
# 0.46

# %% [markdown]
# La sua posizione nel file dei massimi è:

# %%
maxValues.index(maxValue)
# Out:
# 1

# %% [markdown]
# Quindi la precipitazione che massimizza la portata (limitatamente all'insieme di simulazioni che abbiamo fatto) è la prima. Ora ci proponiamo di trovare il tempo in cui il massimo si realizza. Per fare questo dobbiamo considerare il primo dataFrame.

# %%
mask=(n_t1==n_t1.max(0))

# %%
n_t1==n_t1.max(0)
# Out:
# time
# 00:00:30      False
# 00:01:00      False
# 00:01:30      False
# 00:02:00      False
# 00:02:30      False
# 00:03:00      False
# 00:03:30      False
# 00:04:00      False
# 00:04:30      False
# 00:05:00      False
# 00:05:30       True
# 00:06:00       True
# 00:06:30      False
# 00:07:00      False
# 00:07:30      False
# 00:08:00      False
# 00:08:30      False
# 00:09:00      False
# 00:09:30      False
# 00:10:00      False
# 00:10:30      False
# 00:11:00      False
# 00:11:30      False
# 00:12:00      False
# 00:12:30      False
# 00:13:00      False
# 00:13:30      False
# 00:14:00      False
# 00:14:30      False
# 00:15:00      False
#               ...
# 04:45:30      False
# 04:46:00      False
# 04:46:30      False
# 04:47:00      False
# 04:47:30      False
# 04:48:00      False
# 04:48:30      False
# 04:49:00      False
# 04:49:30      False
# 04:50:00      False
# 04:50:30      False
# 04:51:00      False
# 04:51:30      False
# 04:52:00      False
# ...

# %%
n_t1[mask]
# Out:
# time
# 00:05:30      0.23
# 00:06:00      0.23
# Name: 5mins, dtype: float64

# %% [markdown]
# Il tempo di pioggia critico risulta:

# %%
n_t1[mask].index
# Out:
# Index(['00:05:30  ', '00:06:00  '], dtype='object', name='time')
